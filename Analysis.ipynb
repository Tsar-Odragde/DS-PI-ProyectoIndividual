# %%
import pandas as pd
import numpy as np

# %%
cliente = pd.read_csv('./Datasets/Clientes.csv', sep=';')
cliente.head()
# Out:
#    ID     Provincia        Nombre_y_Apellido  \
# 0   1  Buenos Aires       HEBER JONI SANTANA
# 1   2  Buenos Aires              ANA SAPRIZA
# 2   3  Buenos Aires  FERNANDO LUIS SARALEGUI
# 3   4  Buenos Aires         MANUELA SARASOLA
# 4   5  Buenos Aires       MARIO RAÚL SARASUA
#
#                                            Domicilio  Telefono  Edad  \
# 0  LAS HERAS Y BAT. 24 DE FEBRERO 4150  RINCON DE...   42-5161    58
# 1  PUEYRREDON Y DUPUY RUTA3 KM 52.500 S/N  BÂº LO...   49-7578    61
# 2                           CALDERON DE LA BARCA 498   49-3435    15
# 3                  RUTA 36 KM 45,500 S/N  EL PELIGRO   49-2883    29
# 4                     492 Y 186 S/N  COLONIA URQUIZA  491-4608    34
#
#              Localidad             X             Y  col10
# 0           LOMA VERDE  -58,81850307  -34,30997088    NaN
# 1           SANTA ROSA  -58,73073751  -34,93908311    NaN
# 2               TORRES  -59,12794068  -34,43082199    NaN
# 3             RUTA SOL  -58,14393954  -34,92052706    NaN
# 4  JOSE MELCHOR ROMERO    -58,089381   -34,9444471    NaN

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2672 entries, 0 to 2671
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 2672 non-null   int64
#  1   Provincia          2647 non-null   object
#  2   Nombre_y_Apellido  2648 non-null   object
#  3   Domicilio          2630 non-null   object
#  4   Telefono           2637 non-null   object
#  5   Edad               2672 non-null   int64
#  6   Localidad          2647 non-null   object
#  7   X                  2616 non-null   object
#  8   Y                  2618 non-null   object
#  9   col10              0 non-null      float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 208.9+ KB

# %%
cliente.isna().sum()
# Out:
# ID                      0
# Provincia              25
# Nombre_y_Apellido      24
# Domicilio              42
# Telefono               35
# Edad                    0
# Localidad              25
# X                      56
# Y                      54
# col10                2672
# dtype: int64

# %%
cliente.nunique()
# Out:
# ID                   2672
# Provincia               3
# Nombre_y_Apellido    2592
# Domicilio            2628
# Telefono             2635
# Edad                   51
# Localidad             378
# X                    2610
# Y                    2612
# col10                   0
# dtype: int64

# %%
cliente.loc[cliente.Provincia.isna()]
# Out:
#         ID Provincia              Nombre_y_Apellido  \
# 11      12       NaN          EDUARDO VICENTE SARNI
# 14      15       NaN          JESUS EDUARDO SARUTTE
# 19      20       NaN       ANDRES ALBERTO SCAGLIOLA
# 202    203       NaN                 MERCEDES TRIGO
# 205    206       NaN           SILVANA MARIA TROTTO
# 784    785       NaN        Fernandez, Anibal Oscar
# 795    796       NaN              Real, Victor Hugo
# 804    805       NaN                 Kepa, Carlos D
# 819    820       NaN       Rodriguez, Ruben Osvaldo
# 848    849       NaN    REINEL ANTONIO ARIZA NIEVES
# 866    867       NaN           MARYLIN OTERO ACOSTA
# 1236  1237       NaN              MARTIN DIBARBOURE
# 1751  1752       NaN               RAFAEL PATERNAIN
# 1753  1754       NaN            RITA BEATRIZ PATRON
# 1755  1756       NaN                ANA MARIA PAVON
# 1810  1811       NaN                     JENNY READ
# 1825  1826       NaN       ALEJANDRO DANIEL REPETTO
# 1829  1830       NaN             CARLOS NICOLAS REY
# 1835  1836       NaN                  ALFREDO REYES
# 1845  1846       NaN        WASHINGTON RAUL RIBEIRO
# 1870  1871       NaN                   JORGE RUIBAL
# 2465  2466       NaN  BEATRIZ ELENA MEDINA QUINTERO
# 2555  2556       NaN              JULIO CESAR BANGO
# 2585  2586       NaN              MARIO NELGAR DIAZ
# 2631  2632       NaN                JOAQUIN PICARDO
#
#                                               Domicilio      Telefono  Edad  \
# 11                         CARLOS TEJEDOR 444  EL PINAR     4480-0769    52
# 14                          52 Y 235 S/N  ESQUINA NEGRA      496-4503    25
# 19                          RUTA 15 Y 74 S/N  LOS TALAS      462-0411    24
# 202                                      L. N. ALEM 387       47-7194    31
# 205   GODOY CRUZ Y R. DE ESCALADA S/N  BARRIO SAN MA...       47-7952    28
# 784                                             22 1338      451-0607    20
# 795                                     2 BIS Y 515 S/N      471-4086    52
# 804                                   RUTA 36 Y 529 S/N      491-6025    45
# 819                                     7 (ESQ. 32) S/N      422-4898    43
# 848        CHIRIPA Y LA QUERENCIA 623  BARRIO EL GAUCHO     4238-7458    21
# 866                  SCALABRINI ORTIZ 2561  VILLA PARIS       42-7372    39
# 1236                                JOSE HERNANDEZ 2210     4236-6325    17
# 1751   RUTA PROVINCIAL 28 KM 6 S/N  ENTIQUIANA DEL PEON      440-9043    57
# 1753             LOS CEIBOS - RIO LUJAN s/n  EL CAZADOR       48-8125    59
# 1755                                   RUTA 8 KM 78 S/N       47-8060    16
# 1810       LUIS SIRONI Y RTA.PCIAL NÂº6 S/N  CUARTEL II  15-5341-2821    56
# 1825                  RIO PARANA MINI S/N  PARAJE ISLAS     4728-1891    62
# 1829  ARROYO CARACOLES S/N  PJE.ISLAS DEL DELTA 2Âª ...     4728-1918    18
# 1835  RIO LUJAN Y ARROYO EL CORRENTINO S/N  SECCION ...       46-0230    65
# 1845                RUTA NAC.6 Y RUTA 53   Los RetoÃ±os   15-524-1492    60
# 1870  RUTA 8 KM 85 CUARTEL IV S/N  PARAJE PUENTE DE ...       49-2278    38
# 2465                     CALLE PUBLICA  COOP. 2 DE MAYO        449099    52
# 2555            MARIANO MANSILLA 1025 COLINAS DEL CERRO       4348386    52
# 2585  FELIX ROBIN FERREYRA 2324 ALTO ALBERDI Av. San...       4347835    45
# 2631                          CALLE PUBLICA  S.M.A.T.A.       4344129    43
#
#      Localidad             X             Y  col10
# 11         NaN  -58,57950173  -34,82788055    NaN
# 14         NaN  -58,07461366  -35,03160025    NaN
# 19         NaN  -57,80754132   -34,8980234    NaN
# 202        NaN  -58,38185254  -34,91321374    NaN
# 205        NaN   -58,3923462  -34,93104911    NaN
# 784        NaN  -57,95322986   -34,9374101    NaN
# 795        NaN  -57,98310019  -34,88246253    NaN
# 804        NaN  -58,06003018  -34,97705791    NaN
# 819        NaN  -57,96847377  -34,90064659    NaN
# 848        NaN  -58,36957529  -34,81900036    NaN
# 866        NaN  -58,37910613  -34,87911199    NaN
# 1236       NaN  -58,35201173  -34,80927702    NaN
# 1751       NaN  -58,92410576  -34,51268547    NaN
# 1753       NaN  -58,77149257  -34,28843088    NaN
# 1755       NaN  -59,13493544    -34,371831    NaN
# 1810       NaN  -59,04010696  -34,62514282    NaN
# 1825       NaN   -58,5197955  -34,15111301    NaN
# 1829       NaN  -58,51497069  -34,24406526    NaN
# 1835       NaN  -58,72164835  -34,29769297    NaN
# 1845       NaN  -58,22999374  -35,02407669    NaN
# 1870       NaN  -59,20674955  -34,35546074    NaN
# 2465       NaN    -64,254078    -31,318754    NaN
# 2555       NaN  -64,24812339  -31,37918888    NaN
# 2585       NaN  -64,21587337  -31,41489553    NaN
# 2631       NaN  -64,22252811  -31,45246554    NaN

# %%
cliente.loc[cliente.Nombre_y_Apellido.isna()]
# Out:
#         ID     Provincia Nombre_y_Apellido  \
# 1081  1082  Buenos Aires               NaN
# 1332  1333  Buenos Aires               NaN
# 1337  1338  Buenos Aires               NaN
# 1359  1360  Buenos Aires               NaN
# 1389  1390  Buenos Aires               NaN
# 1617  1618  Buenos Aires               NaN
# 1748  1749  Buenos Aires               NaN
# 1763  1764  Buenos Aires               NaN
# 1852  1853  Buenos Aires               NaN
# 1855  1856  Buenos Aires               NaN
# 1856  1857  Buenos Aires               NaN
# 1859  1860  Buenos Aires               NaN
# 1861  1862  Buenos Aires               NaN
# 1863  1864  Buenos Aires               NaN
# 2340  2341       Córdoba               NaN
# 2490  2491       Córdoba               NaN
# 2529  2530       Córdoba               NaN
# 2569  2570       Córdoba               NaN
# 2570  2571       Córdoba               NaN
# 2571  2572       Córdoba               NaN
# 2576  2577       Córdoba               NaN
# 2587  2588       Córdoba               NaN
# 2588  2589       Córdoba               NaN
# 2613  2614       Córdoba               NaN
#
#                                               Domicilio         Telefono  \
# 1081                         BELIERA Y RUTA 26 KM 5 S/N          48-3120
# 1332  LOS ROBLES E/JACARANDAES Y P.BORRACHOS 108  PA...        4283-4029
# 1337          AVENIDA HIPOLITO YRIGOYEN Y LARROQUE 7672        4242-0635
# 1359            L.DE LA TORRE E/GAONA E INGENIEROS 2264        4283-1479
# 1389               AZAMOR E/ LARRAZABAL Y MJURATURE 297        4276-2010
# 1617                   RODRIGUEZ PEÃ?A 145  MERLO NORTE         482-1483
# 1748  RIO LUJAN - VILLA IRSA - CUARTEL V S/N  RIO LU...          48-4266
# 1763                       7 Y 643 S/N  VILLA GARIBALDI         491-0615
# 1852                CUARTEL III S/N  PARAJE SAMBOROMBON       15-67-0706
# 1855                        CHIRAMBERRO Y SARMIENTO 489          49-1120
# 1856                    RUTA 215 KM 68 S/N  LOS MERINOS              NaN
# 1859  CAMINO VECINAL A G. RODRIGUEZ CUARTELV S/N  CU...      15-501-4380
# 1861         CUARTEL XI RUTA PROV.193 S/N  LOS MANUELES       15-41-7384
# 1863              ARROYO FELICARIA S/N  2DA SECC. ISLAS        4728-1849
# 2340  MOLLEYACO ESQ.PAYEN S/N BARRIO CERRO NORTE MOL...           449085
# 2490       AV. ARTURO CAPDEVILA KM 9 S/NÂº VILLA ESQUIU  4999125/4999921
# 2529       DIAZ DE LA FUENTE 3101 MATIENZO BÂ° MATIENZO          4343474
# 2569                      JULIAN PAZ 1851 VILLA CABRERA          4347870
# 2570                         AV.ELIAS YOFRE 1095 JARDIN          4646909
# 2571  DAGUERRE 5100 ALMIRANTE BROWN CNO. A CAPILLA D...          4348889
# 2576                    MARTIN ALLENDE 2005 YOFRE NORTE          4529860
# 2587                    PEDRO L. DE CABRERA 3070 JARDIN          4334228
# 2588                  Soldado Pizarro. CALLE 15  INAUDI          4949754
# 2613            JULIAN LAGUNA 2600 AMPLIACION SAN JORGE          4335117
#
#       Edad         Localidad             X             Y  col10
# 1081    21  MAQUINISTA SAVIO  -58,77632327    -34,410096    NaN
# 1332    60   LOMAS DE ZAMORA  -58,43154139  -34,76525411    NaN
# 1337    23         BANDFIELD  -58,39912494  -34,74451518    NaN
# 1359    54         BANDFIELD   -58,4384484  -34,74820016    NaN
# 1389    16     VILLA FIORITO  -58,44269873  -34,70083958    NaN
# 1617    47             MERLO   -58,7329899  -34,66218051    NaN
# 1748    33         BENAVIDEZ   -58,6481981  -34,37827137    NaN
# 1763    55      VILLA ELVIRA  -57,86410071  -34,97950576    NaN
# 1852    45       SAMBOROMBON  -58,28306176  -35,22079921    NaN
# 1855    30        LOMA VERDE  -58,40544324  -35,27514719    NaN
# 1856    49       LOS MERINOS  -58,43801677   -35,2236903    NaN
# 1859    20         CUARTEL V  -58,88936902  -34,73841486    NaN
# 1861    24      LOS MANUELES  -59,29943236  -34,36796601    NaN
# 1863    37             ISLAS  -58,53375348  -34,22242442    NaN
# 2340    22           CORDOBA  -64,27980081   -31,3232745    NaN
# 2490    33           CORDOBA  -64,10788088  -31,35910792    NaN
# 2529    65           CORDOBA  -64,23711582  -31,44527022    NaN
# 2569    21           CORDOBA  -64,20872478  -31,38860733    NaN
# 2570    51           CORDOBA   -64,1798456  -31,45057448    NaN
# 2571    25           CORDOBA  -64,09287247   -31,4589536    NaN
# 2576    23           CORDOBA  -64,12915309    -31,385403    NaN
# 2587    16           CORDOBA  -64,17159864   -31,4475665    NaN
# 2588    26           CORDOBA  -64,19363826  -31,47670021    NaN
# 2613    24           CORDOBA  -64,13358155  -31,37227386    NaN

# %%
cliente.loc[cliente.Domicilio.isna()]
# Out:
#         ID     Provincia                            Nombre_y_Apellido  \
# 140    141  Buenos Aires                                  DORA SZAFIR
# 526    527  Buenos Aires                   Gimenez Mora, Blas Ignacio
# 536    537  Buenos Aires                                Bigatti, Jose
# 568    569  Buenos Aires                          Maldonado, Bernardo
# 611    612  Buenos Aires                          Sanchez, Raul Angel
# 627    628  Buenos Aires                      Usarralde , Juan Martin
# 629    630  Buenos Aires                               Lagos, Osvaldo
# 633    634  Buenos Aires                     Varela, Norberto Enrique
# 637    638  Buenos Aires                    Vicentini, Carlos Natalio
# 640    641  Buenos Aires                           Avalos, Jorge Luis
# 647    648  Buenos Aires  Rodriguez, Rodolfo DanielHarambure, Leandro
# 752    753  Buenos Aires                       Bazand Calderon , Jose
# 829    830  Buenos Aires                 MARIANELLA CARDENAS GONZALEZ
# 1006  1007  Buenos Aires                                CECILIA CAIRO
# 1097  1098  Buenos Aires                                  RENE CHAGAS
# 1099  1100  Buenos Aires                           JULIO CESAR CHALAR
# 1132  1133  Buenos Aires                          JOSE ENRIQUE COLMAN
# 1133  1134  Buenos Aires                         CARLOS VICENTE COLOM
# 1137  1138  Buenos Aires                  KARL FREDERICK CONSOLANDICH
# 1152  1153  Buenos Aires                                UDISON CORREA
# 1189  1190  Buenos Aires                                 JUAN CURBELO
# 1305  1306  Buenos Aires                        LINA SILVIA FERNANDEZ
# 1311  1312  Buenos Aires                          ELEUTERIO FERNANDEZ
# 1317  1318  Buenos Aires                                 ALDO FERRARI
# 1338  1339  Buenos Aires                            SEBASTIAN FERRERO
# 1360  1361  Buenos Aires                       FERNANDO DANIEL FONTAN
# 1469  1470  Buenos Aires                           LUIS ALBERTO GETAL
# 1473  1474  Buenos Aires                    SUSANA BEATRIZ GIANARELLI
# 1489  1490  Buenos Aires                               MARTHA GIUDICE
# 1496  1497  Buenos Aires                         CRISTINA --- GOITIÑO
# 1504  1505  Buenos Aires                          ALFREDO DARIO GOMEZ
# 1505  1506  Buenos Aires                                RICARDO GOMEZ
# 1522  1523  Buenos Aires                               PABLO GONZALEZ
# 1528  1529  Buenos Aires                      MARIA CRISTINA GONZALEZ
# 1533  1534  Buenos Aires                       ADRIANA MARIA GONZALEZ
# 1581  1582  Buenos Aires                           ALVARO LUIS GUINEA
# 1585  1586  Buenos Aires                     JAVIER ENRIQUE GUTIERREZ
# 1605  1606  Buenos Aires                             SILVIO HERNANDEZ
# 1611  1612  Buenos Aires                          ALEJANDRO HERNANDEZ
# 1638  1639  Buenos Aires                        MARIA ESTELA ILUNDAIN
# 2556  2557       Córdoba                       DANIEL HONORIO BARRIOS
# 2639  2640       Córdoba                              CLAUDIO PIÑEYRO
#
#      Domicilio        Telefono  Edad                       Localidad    X  \
# 140        NaN       4690-6533    19                 RAFAEL CASTILLO  NaN
# 526        NaN       4768-0607    20          CIUDAD VILLA BALLESTER  NaN
# 536        NaN       4720-5675    42    CIUDAD JARDIN DEL LIBERTADOR  NaN
# 568        NaN       4284-1547    50                    MONTE GRANDE  NaN
# 611        NaN       4755-0793    64                     VILLA MAIPU  NaN
# 627        NaN       4713-2859    44              PARQUE SAN LORENZO  NaN
# 629        NaN       4720-2374    30          CIUDAD VILLA BALLESTER  NaN
# 633        NaN       4729-9013    48                VILLA GODOY CRUZ  NaN
# 637        NaN       4729-9079    20  VILLA GENERAL EUGENIO NECOCHEA  NaN
# 640        NaN       4768-4734    59         VILLA GREGORIA MATORRAS  NaN
# 647        NaN       4769-4180    33   VILLA CORONEL JOSE M. ZAPIOLA  NaN
# 752        NaN        496-2983    21                ANGEL ETCHEVERRY  NaN
# 829        NaN        421-2978    19                        LA PLATA  NaN
# 1006       NaN         49-3323    18                 VIRREY DEL PINO  NaN
# 1097       NaN         48-2836    59                       BENAVIDEZ  NaN
# 1099       NaN             NaN    27                       BANDFIELD  NaN
# 1132       NaN       4274-7901    24                     VILLA BROWN  NaN
# 1133       NaN       4255-6766    62                FLORENCIO VARELA  NaN
# 1137       NaN       4274-4075    31                VILLA SANTA ROSA  NaN
# 1152       NaN       4237-9095    34        GOBERNADOR JULIO A COSTA  NaN
# 1189       NaN         49-3900    27                 VIRREY DEL PINO  NaN
# 1305       NaN             NaN    32                 GENERAL PACHECO  NaN
# 1311       NaN             NaN    40                 LOMAS DE ZAMORA  NaN
# 1317       NaN             NaN    21                 LOMAS DE ZAMORA  NaN
# 1338       NaN        485-0393    65               GENERAL RODRIGUEZ  NaN
# 1360       NaN             NaN    40                       BANDFIELD  NaN
# 1469       NaN       4625-2470    50                 ISIDRO CASANOVA  NaN
# 1473       NaN         42-6758    27                  GONZALEZ CATAN  NaN
# 1489       NaN       4467-2103    43                 ISIDRO CASANOVA  NaN
# 1496       NaN       4467-1816    16           GREGORIO DE LAFERRERE  NaN
# 1504       NaN         44-7121    22                 VIRREY DEL PINO  NaN
# 1505       NaN         43-6812    27                  GONZALEZ CATAN  NaN
# 1522       NaN       4453-2850    19                   L DEL MIRADOR  NaN
# 1528       NaN         43-6838    45                  GONZALEZ CATAN  NaN
# 1533       NaN       4467-1864    64           GREGORIO DE LAFERRERE  NaN
# 1581       NaN       4698-7924    34           GREGORIO DE LAFERRERE  NaN
# 1585       NaN       4695-3422    63                    CIUDAD EVITA  NaN
# 1605       NaN  4698-8401/5156    41           GREGORIO DE LAFERRERE  NaN
# 1611       NaN       4651-3232    44                       SAN JUSTO  NaN
# 1638       NaN        497-5183    41            SAN ANTONIO DE PADUA  NaN
# 2556       NaN             NaN    17                         CORDOBA  NaN
# 2639       NaN          487942    33                        UNQUILLO  NaN
#
#         Y  col10
# 140   NaN    NaN
# 526   NaN    NaN
# 536   NaN    NaN
# 568   NaN    NaN
# 611   NaN    NaN
# 627   NaN    NaN
# 629   NaN    NaN
# 633   NaN    NaN
# 637   NaN    NaN
# 640   NaN    NaN
# 647   NaN    NaN
# 752   NaN    NaN
# 829   NaN    NaN
# 1006  NaN    NaN
# 1097  NaN    NaN
# 1099  NaN    NaN
# 1132  NaN    NaN
# 1133  NaN    NaN
# 1137  NaN    NaN
# 1152  NaN    NaN
# 1189  NaN    NaN
# 1305  NaN    NaN
# 1311  NaN    NaN
# 1317  NaN    NaN
# 1338  NaN    NaN
# 1360  NaN    NaN
# 1469  NaN    NaN
# 1473  NaN    NaN
# 1489  NaN    NaN
# 1496  NaN    NaN
# 1504  NaN    NaN
# 1505  NaN    NaN
# 1522  NaN    NaN
# 1528  NaN    NaN
# 1533  NaN    NaN
# 1581  NaN    NaN
# 1585  NaN    NaN
# 1605  NaN    NaN
# 1611  NaN    NaN
# 1638  NaN    NaN
# 2556  NaN    NaN
# 2639  NaN    NaN

# %%
cliente.loc[cliente.Telefono.isna()]
# Out:
#         ID     Provincia             Nombre_y_Apellido  \
# 532    533  Buenos Aires       Umansky, Roberto Rafael
# 725    726  Buenos Aires      Biondini, Roberto Miguel
# 727    728  Buenos Aires       Mamani , Mario Fernando
# 862    863  Buenos Aires  DIANA COLOMBIA GARCIA GELVES
# 1099  1100  Buenos Aires            JULIO CESAR CHALAR
# 1181  1182  Buenos Aires                  DANUBIO CRUZ
# 1196  1197  Buenos Aires  HOMERO HECTOR DA COSTA PORTO
# 1209  1210  Buenos Aires   MARTIN ISMAEL DALGALARRONDO
# 1249  1250  Buenos Aires                 IRMA ESQUIVEL
# 1305  1306  Buenos Aires         LINA SILVIA FERNANDEZ
# 1311  1312  Buenos Aires           ELEUTERIO FERNANDEZ
# 1317  1318  Buenos Aires                  ALDO FERRARI
# 1360  1361  Buenos Aires        FERNANDO DANIEL FONTAN
# 1378  1379  Buenos Aires               FRANCO FREDUCCI
# 1688  1689  Buenos Aires    EDISON HERIBERTO KRASOVSKI
# 1744  1745  Buenos Aires          ANDRES FERNANDO LESA
# 1758  1759  Buenos Aires       RODOLFO CARLOS PEDOCCHI
# 1760  1761  Buenos Aires       ROBERTO GUZMAN PEDREIRA
# 1761  1762  Buenos Aires          ANGEL ROQUE PEDREIRA
# 1762  1763  Buenos Aires             ALEJANDRA PEDULLA
# 1784  1785  Buenos Aires    CLAUDIO  REYNALDO QUINTANA
# 1802  1803  Buenos Aires                 DANIELA RAMOS
# 1814  1815  Buenos Aires       GONZALO JAVIER REBOLEDO
# 1836  1837  Buenos Aires          MARGARITA ROSA REYES
# 1847  1848  Buenos Aires       DARDO EDUARDO RODRIGUEZ
# 1850  1851  Buenos Aires             ARACELY RODRIGUEZ
# 1856  1857  Buenos Aires                           NaN
# 2458  2459       Córdoba   JHON FABER GONZALEZ MOSCOSO
# 2491  2492       Córdoba         JOSE BARTOLOME ACOSTA
# 2532  2533       Córdoba                  SYLVIA AMADO
# 2556  2557       Córdoba        DANIEL HONORIO BARRIOS
# 2567  2568       Córdoba          NELSON MARIO CABRERA
# 2615  2616       Córdoba         HERMES RAUL PASTORINI
# 2635  2636       Córdoba    RODOLFO WASHINGTON PICCINI
# 2649  2650       Córdoba                  ANDRES RIDAO
#
#                                               Domicilio Telefono  Edad  \
# 532                                SUIPACHA Y NAON 5731      NaN    48
# 725          ALFONSINA STORNI E/LA PLATA Y LA TABLA S/N      NaN    17
# 727            BARRIO VILLA ARRARAS   BÂº VILLA ARRARAS      NaN    65
# 862       LOS STUDS E/ BS AS Y ESPAÃ?A S/N  RAYO DE SOL      NaN    23
# 1099                                                NaN      NaN    27
# 1181                     LIMA Y PUNCH   BÂº SOL Y VERDE      NaN    49
# 1196                            447 E/ MONTEVERDE Y 400      NaN    62
# 1209                                        RIGLOS 4866      NaN    57
# 1249  CAMINO AL PARQUE INDUSTRIAL (CUAR.III) S/N  CO...      NaN    54
# 1305                                                NaN      NaN    32
# 1311                                                NaN      NaN    40
# 1317                                                NaN      NaN    21
# 1360                                                NaN      NaN    40
# 1378         LA HAYA Y RICARDO PALMA   BARRIO F.QUIROGA      NaN    52
# 1688      ESCALADA Y REMBRANDT S/N  BARRIO EL AGUARIBAY      NaN    40
# 1744                           1 BIS E/ BOULEVARD 2 Y 3      NaN    49
# 1758  SANCHEZ DE BUST. E/MALABIA Y MEDRANO S/N  BARR...      NaN    65
# 1760                      BELIERA E/ COLON Y BRASIL S/N      NaN    23
# 1761   REPETTO E/ LA PLATA Y PATRICIOS   BÂº JUAN XXIII      NaN    52
# 1762                                           411 Y 25      NaN    25
# 1784                     RUTA PROVINCIAL NÂº6 KM 12 S/N      NaN    41
# 1802             RIO PARANA DE LAS PALMAS KM. 117,5 S/N      NaN    21
# 1814              RUTA 34 CAMINOA PILAR S/N  CUARTEL IV      NaN    42
# 1836                     RUTA 52 KM.26 S/N  EL PORVENIR      NaN    37
# 1847                       ZONA RURAL S/N  PARAJE SUCRE      NaN    57
# 1850           TERESA MASTELLONE S/N  BARRIO GRANADEROS      NaN    54
# 1856                    RUTA 215 KM 68 S/N  LOS MERINOS      NaN    49
# 2458    RUTA 9-S-KM 689 S/NÂº 25 DE MAYO BÂ° 25 DE MAYO      NaN    27
# 2491  CALLE PUBLICA S/NÂº  29 DE MAYO CORDOBA - CIUD...      NaN    30
# 2532        LAS ANEMONAS 2231 CUESTA COLORADA LA CALERA      NaN    31
# 2556                                                NaN      NaN    17
# 2567  JUAN RAMON ROJAS  CIUDAD AMPLIACION FERREYRA B...      NaN    43
# 2615                BEJANELE 6200 I.P.V. ARGUELLO NORTE      NaN    34
# 2635    CALLE PUBLICA  SOL NACIENTE BARRIO SOL NACIENTE      NaN    44
# 2649                CALLE PUBLICA S/NÂº  POZO DEL TIGRE      NaN    62
#
#                      Localidad             X             Y  col10
# 532               BILLINGHURST  -58,57816326  -34,57053906    NaN
# 725             MARIANO MORENO   -58,7996827  -34,60805218    NaN
# 727          GENERAL RODRIGUEZ  -58,93636158   -34,5499612    NaN
# 862                 LONGCHAMPS   -58,4072456  -34,87773209    NaN
# 1099                 BANDFIELD           NaN           NaN    NaN
# 1181               TORTUGUITAS  -58,78986507  -34,50580773    NaN
# 1196  GOBERNADOR JULIO A COSTA  -58,31879246  -34,80206225    NaN
# 1209            GONZALEZ CATAN  -58,61950815  -34,75700659    NaN
# 1249                    ZARATE  -59,02493277  -34,09108354    NaN
# 1305           GENERAL PACHECO           NaN           NaN    NaN
# 1311           LOMAS DE ZAMORA           NaN           NaN    NaN
# 1317           LOMAS DE ZAMORA           NaN           NaN    NaN
# 1360                 BANDFIELD           NaN           NaN    NaN
# 1378                 BANDFIELD  -58,45160787  -34,72910731    NaN
# 1688         FRANCISCO ALVAREZ  -58,87959846  -34,58959668    NaN
# 1744               VILLA ELISA  -57,90682784  -34,93561665    NaN
# 1758                VILLA ROSA  -58,85975517  -34,42438174    NaN
# 1760                     GARIN  -58,75268148  -34,42378389    NaN
# 1761                     LUJAN  -59,10399662  -34,54846943    NaN
# 1762               VILLA ELISA  -58,10439972  -34,86434997    NaN
# 1784       BARRIO LOS PIONEROS  -58,96547351  -34,26981951    NaN
# 1802                     ISLAS  -59,09145931  -34,00836392    NaN
# 1814                CUARTEL IV  -58,99801141  -34,54434907    NaN
# 1836               EL PORVENIR   -58,5417323   -34,9628968    NaN
# 1847                     SUCRE  -59,11400635  -34,51513549    NaN
# 1850         BARRIO GRANADEROS  -59,01370012  -34,58744152    NaN
# 1856               LOS MERINOS  -58,43801677   -35,2236903    NaN
# 2458                   CORDOBA    -64,076726    -31,492202    NaN
# 2491                   CORDOBA  -64,12531302  -31,37083811    NaN
# 2532                 LA CALERA  -64,34095356   -31,3405455    NaN
# 2556                   CORDOBA           NaN           NaN    NaN
# 2567                   CORDOBA  -64,11998478  -31,47549286    NaN
# 2615                   CORDOBA  -64,24607679  -31,33191067    NaN
# 2635                   CORDOBA  -64,24296159  -31,32224436    NaN
# 2649            POZO DEL TIGRE   -64,1839443   -31,1067387    NaN

# %%
cliente.Edad.describe()
# Out:
# count    2672.000000
# mean       40.203967
# std        14.611554
# min        15.000000
# 25%        28.000000
# 50%        41.000000
# 75%        53.000000
# max        65.000000
# Name: Edad, dtype: float64

# %%
cliente.loc[cliente.X.isna()]
# Out:
#         ID     Provincia                            Nombre_y_Apellido  \
# 140    141  Buenos Aires                                  DORA SZAFIR
# 155    156  Buenos Aires                          CECILIA RITA TEJERA
# 162    163  Buenos Aires                          ANA MARIA TELLECHEA
# 174    175  Buenos Aires                         HERMES ROMERO TOLEDO
# 188    189  Buenos Aires                                SERGIO TORRES
# 316    317  Buenos Aires                              GRACIELA VILLAR
# 379    380  Buenos Aires                       Martinez, Santiago Alb
# 384    385  Buenos Aires                        Benitez, Romina Paola
# 526    527  Buenos Aires                   Gimenez Mora, Blas Ignacio
# 536    537  Buenos Aires                                Bigatti, Jose
# 547    548  Buenos Aires                            Gallucci, Domingo
# 568    569  Buenos Aires                          Maldonado, Bernardo
# 611    612  Buenos Aires                          Sanchez, Raul Angel
# 627    628  Buenos Aires                      Usarralde , Juan Martin
# 629    630  Buenos Aires                               Lagos, Osvaldo
# 633    634  Buenos Aires                     Varela, Norberto Enrique
# 637    638  Buenos Aires                    Vicentini, Carlos Natalio
# 640    641  Buenos Aires                           Avalos, Jorge Luis
# 647    648  Buenos Aires  Rodriguez, Rodolfo DanielHarambure, Leandro
# 711    712  Buenos Aires    Manrique, Alberto CesarParra, Pablo Ariel
# 732    733  Buenos Aires                       Rizzo, Gabriel Domingo
# 740    741  Buenos Aires               Ovalle Valera , Ricardo Edward
# 752    753  Buenos Aires                       Bazand Calderon , Jose
# 829    830  Buenos Aires                 MARIANELLA CARDENAS GONZALEZ
# 1006  1007  Buenos Aires                                CECILIA CAIRO
# 1010  1011  Buenos Aires                                ROBERTO CALVO
# 1013  1014  Buenos Aires                         LUIS ALBERTO CAMACHO
# 1097  1098  Buenos Aires                                  RENE CHAGAS
# 1099  1100  Buenos Aires                           JULIO CESAR CHALAR
# 1132  1133  Buenos Aires                          JOSE ENRIQUE COLMAN
# 1133  1134  Buenos Aires                         CARLOS VICENTE COLOM
# 1137  1138  Buenos Aires                  KARL FREDERICK CONSOLANDICH
# 1152  1153  Buenos Aires                                UDISON CORREA
# 1189  1190  Buenos Aires                                 JUAN CURBELO
# 1213  1214  Buenos Aires                   ANABELLA ELIZABETH DAMASCO
# 1305  1306  Buenos Aires                        LINA SILVIA FERNANDEZ
# 1311  1312  Buenos Aires                          ELEUTERIO FERNANDEZ
# 1317  1318  Buenos Aires                                 ALDO FERRARI
# 1338  1339  Buenos Aires                            SEBASTIAN FERRERO
# 1360  1361  Buenos Aires                       FERNANDO DANIEL FONTAN
# 1469  1470  Buenos Aires                           LUIS ALBERTO GETAL
# 1473  1474  Buenos Aires                    SUSANA BEATRIZ GIANARELLI
# 1489  1490  Buenos Aires                               MARTHA GIUDICE
# 1496  1497  Buenos Aires                         CRISTINA --- GOITIÑO
# 1504  1505  Buenos Aires                          ALFREDO DARIO GOMEZ
# 1505  1506  Buenos Aires                                RICARDO GOMEZ
# 1522  1523  Buenos Aires                               PABLO GONZALEZ
# 1528  1529  Buenos Aires                      MARIA CRISTINA GONZALEZ
# 1533  1534  Buenos Aires                       ADRIANA MARIA GONZALEZ
# 1581  1582  Buenos Aires                           ALVARO LUIS GUINEA
# 1585  1586  Buenos Aires                     JAVIER ENRIQUE GUTIERREZ
# 1605  1606  Buenos Aires                             SILVIO HERNANDEZ
# 1611  1612  Buenos Aires                          ALEJANDRO HERNANDEZ
# 1638  1639  Buenos Aires                        MARIA ESTELA ILUNDAIN
# 2556  2557       Córdoba                       DANIEL HONORIO BARRIOS
# 2639  2640       Córdoba                              CLAUDIO PIÑEYRO
#
#                                               Domicilio        Telefono  Edad  \
# 140                                                 NaN       4690-6533    19
# 155       SARGENTO DIAZ E/ CORDERO Y CAN 1990  VIRREYES       4744-7607    29
# 162                  G.POSADAS E/ CHARCAS Y SANTANA 606       4743-1353    57
# 174             B. DE IRIGOYEN E/ SEGUROLA Y CAZON 2100       4765-4115    64
# 188                   C.ONELLI E/ M.GARCIA Y GUIDO 2468       4723-1524    33
# 316      ESTANISLAO DEL CAMPO ESQ. GÃ?EMES 777  PADILLA       4760-5931    49
# 379            MAURE Y C. URUGUAYO 3360  LAS HIGUERITAS       4246-0347    18
# 384                            PERGAMINO Y BOUCHARD S/N       4225-2078    53
# 526                                                 NaN       4768-0607    20
# 536                                                 NaN       4720-5675    42
# 547                      ROMA Y CAMINO REAL 188  EZEIZA         43-1051    20
# 568                                                 NaN       4284-1547    50
# 611                                                 NaN       4755-0793    64
# 627                                                 NaN       4713-2859    44
# 629                                                 NaN       4720-2374    30
# 633                                                 NaN       4729-9013    48
# 637                                                 NaN       4729-9079    20
# 640                                                 NaN       4768-4734    59
# 647                                                 NaN       4769-4180    33
# 711                  ITALIA E/ BRAMANTE Y C. VIGIL 4010       4465-5186    60
# 732   CARMEN PUCH E/ PASTEUR Y AGRELO 1781  BARRIO L...         44-6227    54
# 740                G. PINTOS Y PRINGLES S/N  EL COLIBRI       4465-5182    52
# 752                                                 NaN        496-2983    21
# 829                                                 NaN        421-2978    19
# 1006                                                NaN         49-3323    18
# 1010                           COMPOSTELA Y GIRONDO S/N         42-2250    47
# 1013                     BELGRANO E/ PAZ Y ZUBIRIA 1755       4667-4405    16
# 1097                                                NaN         48-2836    59
# 1099                                                NaN             NaN    27
# 1132                                                NaN       4274-7901    24
# 1133                                                NaN       4255-6766    62
# 1137                                                NaN       4274-4075    31
# 1152                                                NaN       4237-9095    34
# 1189                                                NaN         49-3900    27
# 1213  CRUZ DEL SUR E/ AGUERO Y ESPAÃ?A 1954  LA GUARIDA       4455-9133    43
# 1305                                                NaN             NaN    32
# 1311                                                NaN             NaN    40
# 1317                                                NaN             NaN    21
# 1338                                                NaN        485-0393    65
# 1360                                                NaN             NaN    40
# 1469                                                NaN       4625-2470    50
# 1473                                                NaN         42-6758    27
# 1489                                                NaN       4467-2103    43
# 1496                                                NaN       4467-1816    16
# 1504                                                NaN         44-7121    22
# 1505                                                NaN         43-6812    27
# 1522                                                NaN       4453-2850    19
# 1528                                                NaN         43-6838    45
# 1533                                                NaN       4467-1864    64
# 1581                                                NaN       4698-7924    34
# 1585                                                NaN       4695-3422    63
# 1605                                                NaN  4698-8401/5156    41
# 1611                                                NaN       4651-3232    44
# 1638                                                NaN        497-5183    41
# 2556                                                NaN             NaN    17
# 2639                                                NaN          487942    33
#
#                            Localidad    X             Y  col10
# 140                  RAFAEL CASTILLO  NaN           NaN    NaN
# 155                         VIRREYES  NaN  -34,45391448    NaN
# 162                           BECCAR  NaN  -34,46477348    NaN
# 174                 BOULOGNE SUR MER  NaN  -34,49464954    NaN
# 188                           BECCAR  NaN  -34,46701129    NaN
# 316                   VILLA MARTELLI  NaN  -34,54071579    NaN
# 379                       LANUS ESTE  NaN  -34,71304052    NaN
# 384                       LANUS ESTE  NaN  -34,70556988    NaN
# 526           CIUDAD VILLA BALLESTER  NaN           NaN    NaN
# 536     CIUDAD JARDIN DEL LIBERTADOR  NaN           NaN    NaN
# 547                 CARLOS SPEGAZZIN  NaN  -34,89879758    NaN
# 568                     MONTE GRANDE  NaN           NaN    NaN
# 611                      VILLA MAIPU  NaN           NaN    NaN
# 627               PARQUE SAN LORENZO  NaN           NaN    NaN
# 629           CIUDAD VILLA BALLESTER  NaN           NaN    NaN
# 633                 VILLA GODOY CRUZ  NaN           NaN    NaN
# 637   VILLA GENERAL EUGENIO NECOCHEA  NaN           NaN    NaN
# 640          VILLA GREGORIA MATORRAS  NaN           NaN    NaN
# 647    VILLA CORONEL JOSE M. ZAPIOLA  NaN           NaN    NaN
# 711                       SAN MIGUEL  NaN  -34,56658193    NaN
# 732                       JOSE C PAZ  NaN  -34,51432265    NaN
# 740                       SAN MIGUEL  NaN  -34,55590147    NaN
# 752                 ANGEL ETCHEVERRY  NaN           NaN    NaN
# 829                         LA PLATA  NaN           NaN    NaN
# 1006                 VIRREY DEL PINO  NaN           NaN    NaN
# 1010                      JOSE C PAZ  NaN  -34,51731279    NaN
# 1013                      SAN MIGUEL  NaN  -34,54748548    NaN
# 1097                       BENAVIDEZ  NaN           NaN    NaN
# 1099                       BANDFIELD  NaN           NaN    NaN
# 1132                     VILLA BROWN  NaN           NaN    NaN
# 1133                FLORENCIO VARELA  NaN           NaN    NaN
# 1137                VILLA SANTA ROSA  NaN           NaN    NaN
# 1152        GOBERNADOR JULIO A COSTA  NaN           NaN    NaN
# 1189                 VIRREY DEL PINO  NaN           NaN    NaN
# 1213                      SAN MIGUEL  NaN  -34,57126884    NaN
# 1305                 GENERAL PACHECO  NaN           NaN    NaN
# 1311                 LOMAS DE ZAMORA  NaN           NaN    NaN
# 1317                 LOMAS DE ZAMORA  NaN           NaN    NaN
# 1338               GENERAL RODRIGUEZ  NaN           NaN    NaN
# 1360                       BANDFIELD  NaN           NaN    NaN
# 1469                 ISIDRO CASANOVA  NaN           NaN    NaN
# 1473                  GONZALEZ CATAN  NaN           NaN    NaN
# 1489                 ISIDRO CASANOVA  NaN           NaN    NaN
# 1496           GREGORIO DE LAFERRERE  NaN           NaN    NaN
# 1504                 VIRREY DEL PINO  NaN           NaN    NaN
# 1505                  GONZALEZ CATAN  NaN           NaN    NaN
# 1522                   L DEL MIRADOR  NaN           NaN    NaN
# 1528                  GONZALEZ CATAN  NaN           NaN    NaN
# 1533           GREGORIO DE LAFERRERE  NaN           NaN    NaN
# 1581           GREGORIO DE LAFERRERE  NaN           NaN    NaN
# 1585                    CIUDAD EVITA  NaN           NaN    NaN
# 1605           GREGORIO DE LAFERRERE  NaN           NaN    NaN
# 1611                       SAN JUSTO  NaN           NaN    NaN
# 1638            SAN ANTONIO DE PADUA  NaN           NaN    NaN
# 2556                         CORDOBA  NaN           NaN    NaN
# 2639                        UNQUILLO  NaN           NaN    NaN

# %%
cliente.X.loc[cliente.X > '0' ].count()
# Out:
# 44

# %%
cliente.loc[cliente.Y.isna()]
# Out:
#         ID               Provincia  \
# 140    141            Buenos Aires
# 526    527            Buenos Aires
# 536    537            Buenos Aires
# 568    569            Buenos Aires
# 611    612            Buenos Aires
# 627    628            Buenos Aires
# 629    630            Buenos Aires
# 633    634            Buenos Aires
# 637    638            Buenos Aires
# 640    641            Buenos Aires
# 647    648            Buenos Aires
# 752    753            Buenos Aires
# 829    830            Buenos Aires
# 1006  1007            Buenos Aires
# 1097  1098            Buenos Aires
# 1099  1100            Buenos Aires
# 1132  1133            Buenos Aires
# 1133  1134            Buenos Aires
# 1137  1138            Buenos Aires
# 1152  1153            Buenos Aires
# 1189  1190            Buenos Aires
# 1305  1306            Buenos Aires
# 1311  1312            Buenos Aires
# 1317  1318            Buenos Aires
# 1338  1339            Buenos Aires
# 1360  1361            Buenos Aires
# 1469  1470            Buenos Aires
# 1473  1474            Buenos Aires
# 1489  1490            Buenos Aires
# 1496  1497            Buenos Aires
# 1504  1505            Buenos Aires
# 1505  1506            Buenos Aires
# 1522  1523            Buenos Aires
# 1528  1529            Buenos Aires
# 1533  1534            Buenos Aires
# 1581  1582            Buenos Aires
# 1585  1586            Buenos Aires
# 1605  1606            Buenos Aires
# 1611  1612            Buenos Aires
# 1638  1639            Buenos Aires
# 2065  2066  Ciudad de Buenos Aires
# 2115  2116  Ciudad de Buenos Aires
# 2118  2119  Ciudad de Buenos Aires
# 2129  2130  Ciudad de Buenos Aires
# 2162  2163  Ciudad de Buenos Aires
# 2236  2237  Ciudad de Buenos Aires
# 2264  2265  Ciudad de Buenos Aires
# 2320  2321  Ciudad de Buenos Aires
# 2425  2426                 Córdoba
# 2426  2427                 Córdoba
# 2427  2428                 Córdoba
# 2509  2510                 Córdoba
# 2556  2557                 Córdoba
# 2639  2640                 Córdoba
#
#                                 Nombre_y_Apellido  \
# 140                                   DORA SZAFIR
# 526                    Gimenez Mora, Blas Ignacio
# 536                                 Bigatti, Jose
# 568                           Maldonado, Bernardo
# 611                           Sanchez, Raul Angel
# 627                       Usarralde , Juan Martin
# 629                                Lagos, Osvaldo
# 633                      Varela, Norberto Enrique
# 637                     Vicentini, Carlos Natalio
# 640                            Avalos, Jorge Luis
# 647   Rodriguez, Rodolfo DanielHarambure, Leandro
# 752                        Bazand Calderon , Jose
# 829                  MARIANELLA CARDENAS GONZALEZ
# 1006                                CECILIA CAIRO
# 1097                                  RENE CHAGAS
# 1099                           JULIO CESAR CHALAR
# 1132                          JOSE ENRIQUE COLMAN
# 1133                         CARLOS VICENTE COLOM
# 1137                  KARL FREDERICK CONSOLANDICH
# 1152                                UDISON CORREA
# 1189                                 JUAN CURBELO
# 1305                        LINA SILVIA FERNANDEZ
# 1311                          ELEUTERIO FERNANDEZ
# 1317                                 ALDO FERRARI
# 1338                            SEBASTIAN FERRERO
# 1360                       FERNANDO DANIEL FONTAN
# 1469                           LUIS ALBERTO GETAL
# 1473                    SUSANA BEATRIZ GIANARELLI
# 1489                               MARTHA GIUDICE
# 1496                         CRISTINA --- GOITIÑO
# 1504                          ALFREDO DARIO GOMEZ
# 1505                                RICARDO GOMEZ
# 1522                               PABLO GONZALEZ
# 1528                      MARIA CRISTINA GONZALEZ
# 1533                       ADRIANA MARIA GONZALEZ
# 1581                           ALVARO LUIS GUINEA
# 1585                     JAVIER ENRIQUE GUTIERREZ
# 1605                             SILVIO HERNANDEZ
# 1611                          ALEJANDRO HERNANDEZ
# 1638                        MARIA ESTELA ILUNDAIN
# 2065                         JESUS MIGUEL MENDINA
# 2115                      MARTHA SILVANA MONTANER
# 2118                        SYLVIA CARMEN MONTANS
# 2129                         ANGEL MANUEL MORALES
# 2162                                LOURDES MOZZO
# 2236                          HECTOR RAUL OLIVERA
# 2264                             JOSE JAVIER PENA
# 2320                        EDISON MAURICIO PEREZ
# 2425                   HECTOR JOSE TOLOZA FUENTES
# 2426           FABIO ALEXANDER VILLAMIZAR CAMARGO
# 2427        ANGELICA DEL PILAR VILLAMIZAR MORALES
# 2509                           DENISE HAIFA AKIKI
# 2556                       DANIEL HONORIO BARRIOS
# 2639                              CLAUDIO PIÑEYRO
#
#                                               Domicilio             Telefono  \
# 140                                                 NaN            4690-6533
# 526                                                 NaN            4768-0607
# 536                                                 NaN            4720-5675
# 568                                                 NaN            4284-1547
# 611                                                 NaN            4755-0793
# 627                                                 NaN            4713-2859
# 629                                                 NaN            4720-2374
# 633                                                 NaN            4729-9013
# 637                                                 NaN            4729-9079
# 640                                                 NaN            4768-4734
# 647                                                 NaN            4769-4180
# 752                                                 NaN             496-2983
# 829                                                 NaN             421-2978
# 1006                                                NaN              49-3323
# 1097                                                NaN              48-2836
# 1099                                                NaN                  NaN
# 1132                                                NaN            4274-7901
# 1133                                                NaN            4255-6766
# 1137                                                NaN            4274-4075
# 1152                                                NaN            4237-9095
# 1189                                                NaN              49-3900
# 1305                                                NaN                  NaN
# 1311                                                NaN                  NaN
# 1317                                                NaN                  NaN
# 1338                                                NaN             485-0393
# 1360                                                NaN                  NaN
# 1469                                                NaN            4625-2470
# 1473                                                NaN              42-6758
# 1489                                                NaN            4467-2103
# 1496                                                NaN            4467-1816
# 1504                                                NaN              44-7121
# 1505                                                NaN              43-6812
# 1522                                                NaN            4453-2850
# 1528                                                NaN              43-6838
# 1533                                                NaN            4467-1864
# 1581                                                NaN            4698-7924
# 1585                                                NaN            4695-3422
# 1605                                                NaN       4698-8401/5156
# 1611                                                NaN            4651-3232
# 1638                                                NaN             497-5183
# 2065                            OLAYA 1565 VILLA CRESPO            4854-9477
# 2115                     SANCHEZ 1858 VILLA GRAL. MITRE            4581-3497
# 2118           CNEL. APOLINARIO FIGUEROA 1077 CABALLITO            4582-9333
# 2129                       ESTRADA 627 PARQUE CHACABUCO            4923-8717
# 2162                   AVDA. PEDRO GOYENA 984 CABALLITO            4431-1110
# 2236                     BEAUCHEF 1869 PARQUE CHACABUCO            4921-2541
# 2264                                 PUAN 360 CABALLITO            4432-4515
# 2320         DEAN FUNES 1821 PARQUE PATRICIOS 4943-5057  4911-0186/4943-5057
# 2425           AENIDA COLON 2295 ALTO ALBERDI AV. COLON              4347880
# 2426            QUEBRACHO HERRADO ESQ. YAVI  LAS PALMAS              4337317
# 2427                 FRANCISCO DE ARTEAGA  LAS VIOLETAS              4347819
# 2509  SUECIA 2832 PARQUE VELEZ SARSFIELD BÂ° PARQUE ...              4343050
# 2556                                                NaN                  NaN
# 2639                                                NaN               487942
#
#       Edad                       Localidad             X    Y  col10
# 140     19                 RAFAEL CASTILLO           NaN  NaN    NaN
# 526     20          CIUDAD VILLA BALLESTER           NaN  NaN    NaN
# 536     42    CIUDAD JARDIN DEL LIBERTADOR           NaN  NaN    NaN
# 568     50                    MONTE GRANDE           NaN  NaN    NaN
# 611     64                     VILLA MAIPU           NaN  NaN    NaN
# 627     44              PARQUE SAN LORENZO           NaN  NaN    NaN
# 629     30          CIUDAD VILLA BALLESTER           NaN  NaN    NaN
# 633     48                VILLA GODOY CRUZ           NaN  NaN    NaN
# 637     20  VILLA GENERAL EUGENIO NECOCHEA           NaN  NaN    NaN
# 640     59         VILLA GREGORIA MATORRAS           NaN  NaN    NaN
# 647     33   VILLA CORONEL JOSE M. ZAPIOLA           NaN  NaN    NaN
# 752     21                ANGEL ETCHEVERRY           NaN  NaN    NaN
# 829     19                        LA PLATA           NaN  NaN    NaN
# 1006    18                 VIRREY DEL PINO           NaN  NaN    NaN
# 1097    59                       BENAVIDEZ           NaN  NaN    NaN
# 1099    27                       BANDFIELD           NaN  NaN    NaN
# 1132    24                     VILLA BROWN           NaN  NaN    NaN
# 1133    62                FLORENCIO VARELA           NaN  NaN    NaN
# 1137    31                VILLA SANTA ROSA           NaN  NaN    NaN
# 1152    34        GOBERNADOR JULIO A COSTA           NaN  NaN    NaN
# 1189    27                 VIRREY DEL PINO           NaN  NaN    NaN
# 1305    32                 GENERAL PACHECO           NaN  NaN    NaN
# 1311    40                 LOMAS DE ZAMORA           NaN  NaN    NaN
# 1317    21                 LOMAS DE ZAMORA           NaN  NaN    NaN
# 1338    65               GENERAL RODRIGUEZ           NaN  NaN    NaN
# 1360    40                       BANDFIELD           NaN  NaN    NaN
# 1469    50                 ISIDRO CASANOVA           NaN  NaN    NaN
# 1473    27                  GONZALEZ CATAN           NaN  NaN    NaN
# 1489    43                 ISIDRO CASANOVA           NaN  NaN    NaN
# 1496    16           GREGORIO DE LAFERRERE           NaN  NaN    NaN
# 1504    22                 VIRREY DEL PINO           NaN  NaN    NaN
# 1505    27                  GONZALEZ CATAN           NaN  NaN    NaN
# 1522    19                   L DEL MIRADOR           NaN  NaN    NaN
# 1528    45                  GONZALEZ CATAN           NaN  NaN    NaN
# 1533    64           GREGORIO DE LAFERRERE           NaN  NaN    NaN
# 1581    34           GREGORIO DE LAFERRERE           NaN  NaN    NaN
# 1585    63                    CIUDAD EVITA           NaN  NaN    NaN
# 1605    41           GREGORIO DE LAFERRERE           NaN  NaN    NaN
# 1611    44                       SAN JUSTO           NaN  NaN    NaN
# 1638    41            SAN ANTONIO DE PADUA           NaN  NaN    NaN
# 2065    54          CIUDAD DE BUENOS AIRES  -58,44592122  NaN    NaN
# 2115    41          CIUDAD DE BUENOS AIRES  -58,46531818  NaN    NaN
# 2118    30          CIUDAD DE BUENOS AIRES  -58,45242091  NaN    NaN
# 2129    58          CIUDAD DE BUENOS AIRES  -58,43352158  NaN    NaN
# 2162    41          CIUDAD DE BUENOS AIRES  -58,44086926  NaN    NaN
# 2236    23          CIUDAD DE BUENOS AIRES  -58,43020124  NaN    NaN
# 2264    58          CIUDAD DE BUENOS AIRES  -58,44670365  NaN    NaN
# 2320    52          CIUDAD DE BUENOS AIRES  -58,40456728  NaN    NaN
# 2425    35                         CORDOBA  -64,21240656  NaN    NaN
# 2426    31                         CORDOBA  -64,24350836  NaN    NaN
# 2427    32                         CORDOBA  -64,25206415  NaN    NaN
# 2509    52                         CORDOBA  -64,20601019  NaN    NaN
# 2556    17                         CORDOBA           NaN  NaN    NaN
# 2639    33                        UNQUILLO           NaN  NaN    NaN

# %%
cliente.Y.loc[cliente.Y > '0' ].count()
# Out:
# 44

# %%
diccionario_cliente = {
    'Columna_1' : {
        'Título': 'ID',
        'Descripción': 'Índice asociado al cliente.',
        'Tipo de dato': 'Integer',
        'Problemas': 'A simple vista parecería que no tiene conflictos.',
        'Soluciones': 'Ninguna.'
    },
    'Columna_2' : {
        'Título': 'Provincia',
        'Descripción': 'Provincia en la que reside.',
        'Tipo de dato': 'String',
        'Problemas': '25 registros nulos, comparte registros nulos con la columna Localidad.',
        'Soluciones': 'Tratar de sacar el dato del maestro de localidades, si no imputar nulos por "Sin dato".'
    },
    'Columna_3' : {
        'Título': 'Nombre_y_Apellido',
        'Descripción': 'Nombre y Apellidos.',
        'Tipo de dato': 'String',
        'Problemas': '24 registros nulos, estos registros tienen entradas validas en el resto de campos. La columna no está normalizada. Algunas entradas están incompletas. Estos registros tienen las columnas X y Y vacías.',
        'Soluciones': 'Imputar nulos por "Sin dato", normalizar el formato de la columna'
    },
    'Columna_4' : {
        'Título': 'Domicilio',
        'Descripción': 'Dirección en la que reside.',
        'Tipo de dato': 'String',
        'Problemas': '42 registros nulos. Caracteres raros sin importar el encoding que se use.',
        'Soluciones': 'Imputar nulos por "Sin dato"'
    },
    'Columna_5' : {
        'Título': 'Telefono',
        'Descripción': 'Número telefónico asociado al cliente.',
        'Tipo de dato': 'String',
        'Problemas': '35 registros nulos. Algunos campos multivaluados. Columna no normalizada.',
        'Soluciones': 'Imputar nulos por "Sin dato". Eliminar uno de los teléfonos registrados. Normalizar la columna.'
    },
    'Columna_6' : {
        'Título': 'Edad',
        'Descripción': 'Edad.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Aparentemente ninguno.',
        'Soluciones': 'Ninguna.'
    },
    'Columna_7' : {
        'Título': 'Localidad',
        'Descripción': 'Localidad en la que reside.',
        'Tipo de dato': 'String',
        'Problemas': '25 registros nulos, comparte registros nulos con la columna Provincia.',
        'Soluciones': 'Tratar de sacar los datos del maestro de localidades, si no imputar nulos por "Sin dato".'
    },
    'Columna_8' : {
        'Título': 'X',
        'Descripción': 'Coordenadas de longitud del domicilio.',
        'Tipo de dato': 'Decimal',
        'Problemas': '56 registros nulos. 44 registros positivos (Todos deberían ser negativos). Punto decimal representado por coma.',
        'Soluciones': 'Imputar nulos por 0.0. Convertir los positivos. Cambiar la representación del punto decimal.'
    },
    'Columna_9' : {
        'Título': 'Y',
        'Descripción': 'Coordenadas de latitud del domicilio.',
        'Tipo de dato': 'Decimal',
        'Problemas': '54 registros nulos. 44 registros positivos (Todos deberían ser negativos). Punto decimal representado por coma.',
        'Soluciones': 'Imputar nulos por 0.0. Convertir los positivos. Cambiar la representación del punto decimal.'
    },
    'Columna_10' : {
        'Título': 'col10',
        'Descripción': 'Columna vacía.',
        'Tipo de dato': 'NaN',
        'Problemas': 'Toda la columna está vacía.',
        'Soluciones': 'Descartar toda la columna.'
    }
}

# %%
compra = pd.read_csv('./Datasets/Compra.csv', sep=',')
compra.head()
# Out:
#    IdCompra      Fecha  Fecha_Año  Fecha_Mes  Fecha_Periodo  IdProducto  \
# 0         1  1/30/2015       2015          1         201501       42832
# 1         2  1/30/2015       2015          1         201501       42833
# 2         3  1/30/2015       2015          1         201501       42834
# 3         4  1/30/2015       2015          1         201501       42835
# 4         5  1/30/2015       2015          1         201501       42839
#
#    Cantidad  Precio  IdProveedor
# 0        13  560.51           12
# 1        11  497.58            7
# 2         1  588.50            6
# 3         9  567.66           14
# 4        14  231.31            2

# %%
compra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11539 entries, 0 to 11538
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   IdCompra       11539 non-null  int64
#  1   Fecha          11539 non-null  object
#  2   Fecha_Año      11539 non-null  int64
#  3   Fecha_Mes      11539 non-null  int64
#  4   Fecha_Periodo  11539 non-null  int64
#  5   IdProducto     11539 non-null  int64
#  6   Cantidad       11539 non-null  int64
#  7   Precio         11172 non-null  float64
#  8   IdProveedor    11539 non-null  int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 811.5+ KB

# %%
compra.isna().sum()
# Out:
# IdCompra           0
# Fecha              0
# Fecha_Año          0
# Fecha_Mes          0
# Fecha_Periodo      0
# IdProducto         0
# Cantidad           0
# Precio           367
# IdProveedor        0
# dtype: int64

# %%
compra.describe()
# Out:
#            IdCompra     Fecha_Año     Fecha_Mes  Fecha_Periodo    IdProducto  \
# count  11539.000000  11539.000000  11539.000000   11539.000000  11539.000000
# mean    5770.000000   2017.671549      4.570500  201771.725366  42900.634890
# std     3331.166713      1.770288      3.168731     177.830326     83.539532
# min        1.000000   2015.000000      1.000000  201501.000000  42737.000000
# 25%     2885.500000   2016.000000      1.000000  201605.000000  42832.000000
# 50%     5770.000000   2018.000000      4.000000  201801.000000  42902.000000
# 75%     8654.500000   2019.000000      7.000000  201908.000000  42973.000000
# max    11539.000000   2020.000000     12.000000  202012.000000  43043.000000
#
#            Cantidad        Precio   IdProveedor
# count  11539.000000  1.117200e+04  11539.000000
# mean       8.826415  3.613647e+03      7.533928
# std        6.412074  1.006630e+05      3.770609
# min        1.000000  1.860000e+00      1.000000
# 25%        4.000000  3.068300e+02      4.000000
# 50%        7.000000  4.634850e+02      8.000000
# 75%       12.000000  1.260322e+03     11.000000
# max       54.000000  1.044580e+07     14.000000

# %%
compra.nunique()
# Out:
# IdCompra         11539
# Fecha               72
# Fecha_Año            6
# Fecha_Mes           12
# Fecha_Periodo       57
# IdProducto         283
# Cantidad            49
# Precio           10642
# IdProveedor         14
# dtype: int64

# %%
diccionario_compra = {
    'Columna_1' : {
        'Título': 'IdCompra',
        'Descripción': 'Índice asociado a la factura.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguno'
    },
    'Columna_2' : {
        'Título': 'Fecha',
        'Descripción': 'Fecha en la que se realizó la factura.',
        'Tipo de dato': 'Date',
        'Problemas': 'Fecha en formato distinto a las tablas "Gasto" y "Venta".',
        'Soluciones': 'Formatear las fechas como en las otras tablas.'
    },
    'Columna_3' : {
        'Título': 'Fecha_Año',
        'Descripción': 'Año en el que se realizó la factura.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Redundante con la columna Fecha.',
        'Soluciones': 'Dropear la columna para que quede acorde con "Venta" y "Gasto".'
    },
    'Columna_4' : {
        'Título': 'Fecha_Mes',
        'Descripción': 'Número del mes en el que se realizó la factura.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Redundante con la columna Fecha.',
        'Soluciones': 'Dropear la columna para que quede acorde con "Venta" y "Gasto".'
    },
    'Columna_5' : {
        'Título': 'Fecha_Periodo',
        'Descripción': 'Código del período en el que se realizó la factura.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Redundante con la columna Fecha.',
        'Soluciones': 'Dropear la columna para que quede acorde con "Venta" y "Gasto".'
    },
    'Columna_6' : {
        'Título': 'IdProducto',
        'Descripción': 'Índice del producto facturado.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Columna irrelevante ya que no tengo la tabla "Producto" para referirla.',
        'Soluciones': 'Dropear la columna ya que esta no es relevante en esta ocasión.'
    },
    'Columna_7' : {
        'Título': 'Cantidad',
        'Descripción': 'Número de productos facturados.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Algunos outliers.',
        'Soluciones': 'Detectar y marcar los outliers.'
    },
    'Columna_8' : {
        'Título': 'Precio',
        'Descripción': 'Valor unitario del producto.',
        'Tipo de dato': 'Decimal',
        'Problemas': '367 valores nulos. Algunos outliers.',
        'Soluciones': 'Imputar los valores nulos con 0.0. Detectar y marcar los outliers.'
    },
    'Columna_9' : {
        'Título': 'IdProveedor',
        'Descripción': 'Índice del proveedor del producto.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Aparentemente ninguno.',
        'Soluciones': 'Ninguna.'
    }
}

# %%
gasto = pd.read_csv('./Datasets/Gasto.csv', sep=',')
gasto.tail()
# Out:
#       IdGasto  IdSucursal  IdTipoGasto       Fecha    Monto
# 8635     8636          23            4  2020-12-01  1180.27
# 8636     8637          24            1  2020-12-01  1152.15
# 8637     8638          24            2  2020-12-01   305.98
# 8638     8639          24            3  2020-12-01   104.32
# 8639     8640          24            4  2020-12-01  1156.31

# %%
gasto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640 entries, 0 to 8639
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IdGasto      8640 non-null   int64
#  1   IdSucursal   8640 non-null   int64
#  2   IdTipoGasto  8640 non-null   int64
#  3   Fecha        8640 non-null   object
#  4   Monto        8640 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 337.6+ KB

# %%
gasto.describe()
# Out:
#            IdGasto   IdSucursal  IdTipoGasto        Monto
# count  8640.000000  8640.000000  8640.000000  8640.000000
# mean   4320.500000    15.600000     2.500000   659.919324
# std    2494.297496     8.815649     1.118099   448.630839
# min       1.000000     1.000000     1.000000   100.000000
# 25%    2160.750000     8.000000     1.750000   255.022500
# 50%    4320.500000    15.500000     2.500000   679.990000
# 75%    6480.250000    23.000000     3.250000  1100.522500
# max    8640.000000    31.000000     4.000000  1199.880000

# %%
gasto.isna().sum()
# Out:
# IdGasto        0
# IdSucursal     0
# IdTipoGasto    0
# Fecha          0
# Monto          0
# dtype: int64

# %%
gasto.nunique()
# Out:
# IdGasto        8640
# IdSucursal       30
# IdTipoGasto       4
# Fecha            72
# Monto          7033
# dtype: int64

# %%
diccionario_gasto = {
    'Columna_1' : {
        'Título': 'IdGasto',
        'Descripción': 'Índice asociado al gasto.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_2' : {
        'Título': 'IdSucursal',
        'Descripción': 'Índice de la sucursal en la que se realizó el gasto.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_3' : {
        'Título': 'IdTipoGasto',
        'Descripción': 'Índice del tipo de gasto realizado.',
        'Tipo de dato': 'Integer',
        'Problemas': 'No tengo la tabla "TipoGasto" para referenciarla.',
        'Soluciones': 'Dropear la columna ya que el dato es irrelevante en su forma actual.'
    },
    'Columna_4' : {
        'Título': 'Fecha',
        'Descripción': 'Fecha en la que se realizó el gasto.',
        'Tipo de dato': 'Date',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_5' : {
        'Título': 'Monto',
        'Descripción': 'Importe correspondiente.',
        'Tipo de dato': 'Decimal',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    }
}

# %%
localidad = pd.read_csv('./Datasets/Localidades.csv', sep=',')
localidad.head()
# Out:
#                            categoria  centroide_lat  centroide_lon  \
# 0                   Localidad simple     -35.033073     -60.280620
# 1                   Localidad simple     -34.868119     -60.393971
# 2  Componente de localidad compuesta     -35.068014     -60.402597
# 3                   Localidad simple     -35.124382     -60.220061
# 4                   Localidad simple     -35.109618     -60.070551
#
#    departamento_id departamento_nombre fuente          id  \
# 0           6021.0             Alberti  INDEC  6021010000
# 1           6021.0             Alberti  INDEC  6021020000
# 2           6021.0             Alberti  INDEC  6021030000
# 3           6021.0             Alberti  INDEC  6021040000
# 4           6021.0             Alberti  INDEC  6021050000
#
#    localidad_censal_id localidad_censal_nombre  municipio_id municipio_nombre  \
# 0              6021010                 Alberti       60021.0          Alberti
# 1              6021020           Coronel Seguí       60021.0          Alberti
# 2              6021030                 Mechita       60021.0          Alberti
# 3              6021040                     Pla       60021.0          Alberti
# 4              6021050          Villa Grisolía       60021.0          Alberti
#
#            nombre  provincia_id provincia_nombre
# 0         ALBERTI             6     Buenos Aires
# 1   CORONEL SEGUI             6     Buenos Aires
# 2         MECHITA             6     Buenos Aires
# 3             PLA             6     Buenos Aires
# 4  VILLA GRISOLIA             6     Buenos Aires

# %%
# Tabla maestro de localidad, contiene algunos campos irrelevantes a nuesto estudio.
diccionario_localidad = {
    'Columna_1' : {
        'Título': 'categoría',
        'Descripción': 'Tipos posibles de localidad.',
        'Tipo de dato': 'String'
    },
    'Columna_2' : {
        'Título': 'centroide_lat',
        'Descripción': 'Coordenadas de latitud correspondientes.',
        'Tipo de dato': 'Decimal'
    },
    'Columna_3' : {
        'Título': 'centroide_lon',
        'Descripción': 'Coordenadas de longitud correspondientes.',
        'Tipo de dato': 'Decimal'
    },
    'Columna_4' : {
        'Título': 'departamento_id',
        'Descripción': 'Índice correspondiente al departamento del que hace parte.',
        'Tipo de dato': 'Decimal'
    },
    'Columna_5' : {
        'Título': 'departamento_nombre',
        'Descripción': 'Nombre del departamento del que hace parte.',
        'Tipo de dato': 'String'
    },
    'Columna_6' : {
        'Título': 'fuente',
        'Descripción': 'Procedencia del dato.',
        'Tipo de dato': 'String'
    },
    'Columna_7' : {
        'Título': 'id',
        'Descripción': 'Índice correspondiente a la localidad.',
        'Tipo de dato': 'Integer'
    },
    'Columna_8' : {
        'Título': 'localidad_censal_id',
        'Descripción': 'Índice correspondiente a la localidad cuando esta última es definida por parámetros censales.',
        'Tipo de dato': 'Integer'
    },
    'Columna_9' : {
        'Título': 'localidad_censal_nombre',
        'Descripción': 'Nombre correspondiente a la localidad cuando esta última es definida por parámetros censales.',
        'Tipo de dato': 'String'
    },
    'Columna_10' : {
        'Título': 'municipio_id',
        'Descripción': 'Índice correspondiente al municipio del que hace parte.',
        'Tipo de dato': 'Decimal'
    },
    'Columna_11' : {
        'Título': 'municipio_nombre',
        'Descripción': 'Nombre correspondiente al municipio del que hace parte.',
        'Tipo de dato': 'String'
    },
    'Columna_12' : {
        'Título': 'nombre',
        'Descripción': 'Nomenclatura de la localidad.',
        'Tipo de dato': 'String'
    },
    'Columna_13' : {
        'Título': 'provincia_id',
        'Descripción': 'Índice correspondiente a la provincia de la hace parte.',
        'Tipo de dato': 'Integer'
    },
    'Columna_14' : {
        'Título': 'provincia_nombre',
        'Descripción': 'Nombre correspondiente a la provincia del que hace parte.',
        'Tipo de dato': 'String'
    }
}

# %%
proveedor = pd.read_csv('./Datasets/Proveedores.csv', sep=',', encoding='latin-1')
proveedor
# Out:
#     IDProveedor                  Nombre                   Address  \
# 0             1                     NaN           BEREGUESTEIN 36
# 1             2              San Cirano               ALBERTI 965
# 2             3               Bell S.A.                MORENO 331
# 3             4          Rivero Insumos           PTE. PERON 3872
# 4             5     Laprida Computacion  AVDA. PEDRO PEREYRA 1339
# 5             6  Importadora Mann Kloss         LOPE DE VEGA 2102
# 6             7      Fletes y Logistica           SANTA ROSA 1564
# 7             8                     NaN           SANTA ROSA 1564
# 8             9    Via Chile Containers         JUAN B. JUSTO 415
# 9            10              Full Toner               CORDOBA 246
# 10           11    Via Chile Containers     VICEALTE O CONNOR 847
# 11           12     Central Rosario SRL           SAN MARTIN 4816
# 12           13          María Rivarola  SANTIAGO DEL ESTERO 1020
# 13           14            Río Full Net              BELGRANO 244
#
#                              City         State    Country  departamen
# 0                      AVELLANEDA  BUENOS AIRES  ARGENTINA  AVELLANEDA
# 1                CORONEL BRANDSEN  BUENOS AIRES  ARGENTINA    BRANDSEN
# 2                         CAMPANA  BUENOS AIRES  ARGENTINA     CAMPANA
# 3                 VALENTIN ALSINA  BUENOS AIRES  ARGENTINA       LANUS
# 4                         LAPRIDA  BUENOS AIRES  ARGENTINA     LAPRIDA
# 5   BOCA DE ATENCION MONTE CASTRO          CABA  ARGENTINA   COMUNA 10
# 6                         CORDOBA       CORDOBA  ARGENTINA     CAPITAL
# 7                         CORDOBA       CORDOBA  ARGENTINA     CAPITAL
# 8                         MENDOZA       MENDOZA  ARGENTINA     CAPITAL
# 9                         MENDOZA       MENDOZA  ARGENTINA     CAPITAL
# 10        SAN CARLOS DE BARILOCHE     RIO NEGRO  ARGENTINA   BARILOCHE
# 11                        ROSARIO      SANTA FE  ARGENTINA     ROSARIO
# 12          SAN MIGUEL DE TUCUMAN       TUCUMAN  ARGENTINA     CAPITAL
# 13                       MONTEROS       TUCUMAN  ARGENTINA    MONTEROS

# %%
diccionario_proveedor = {
    'Columna_1' : {
        'Título': 'IDProveedor',
        'Descripción': 'Índice asociado al proveedor.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_2' : {
        'Título': 'Nombre',
        'Descripción': 'Nombre de la empresa.',
        'Tipo de dato': 'String',
        'Problemas': '2 campos nulos.',
        'Soluciones': 'Imputar los valores faltantes por "Sin dato".'
    },
    'Columna_3' : {
        'Título': 'Address',
        'Descripción': 'Dirección de la sucursal.',
        'Tipo de dato': 'String',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_4' : {
        'Título': 'City',
        'Descripción': 'Nombre de la ciudad en la que se encuentra.',
        'Tipo de dato': 'String',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_5' : {
        'Título': 'State',
        'Descripción': 'Nombre de la provincia en la que se encuentra.',
        'Tipo de dato': 'String',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_6' : {
        'Título': 'Country',
        'Descripción': 'Nombre del país en el que se encuentra.',
        'Tipo de dato': 'String',
        'Problemas': 'Sólo hay un valor para todos los registros.',
        'Soluciones': 'Dropear la columna ya que nuestro estudio abarca solo 1 país.'
    },
    'Columna_7' : {
        'Título': 'departamen',
        'Descripción': 'Nombre del departamento en el que se encuentra.',
        'Tipo de dato': 'String',
        'Problemas': 'Columna irrelevante para nuestro estudio, con localidad y provincia tengo suficiente.',
        'Soluciones': 'Dropear columna.'
    }
}

# %%
sucursal = pd.read_csv('./Datasets/Sucursales.csv', sep=';')
sucursal
# Out:
#     ID            Sucursal                                 Direccion  \
# 0    1             Cabildo                          Av. Cabildo 1342
# 1    2           Palermo 1                            Guatemala 5701
# 2    3           Palermo 2        Gral. Lucio Norberto Mansilla 2668
# 3    4          Corrientes                       Av. Corrientes 2352
# 4    5             Almagro                            Venezuela 3650
# 5    6           Caballito                        Av. Rivadavia 4708
# 6    7              Flores                        Av. Rivadavia 5746
# 7    8             Alberdi            Av. Juan Bautista Alberdi 1634
# 8    9            Deposito                             Pedernera 530
# 9   10               Velez              Av. Juan Bautista Justo 7738
# 10  11       Vicente Lopez                             Av. Maipú 829
# 11  12          San Isidro                           Av. Sta Fe 2552
# 12  13             Caseros                Justo José de Urquiza 4770
# 13  14               Moron                                 Salta 250
# 14  15            Castelar                             Sta Rosa 1845
# 15  16           San Justo               Av. Dr. Ignacio Arieta 3451
# 16  17               Lanus  Pres. Tte. Gral. Juan Domingo Perón 3270
# 17  18          Avellaneda                   Av. Bartolomé Mitre 612
# 18  19             Quilmes                    Peatonal Rivadavia 185
# 19  20            La Plata                              Calle 48 974
# 20  21                MDQ1                           San Martín 2544
# 21  22                MDQ2                             Belgrano 2847
# 22  23            Rosario1                       Av. Pellegrini 1138
# 23  24            Rosario2                                Rueda 6349
# 24  25      Córdoba Centro                              Av Colón 251
# 25  26      Córdoba Quiroz                     Av Duarte Quirós 2910
# 26  27  Cerro de las Rosas                     Av. Rafael Núñez 4764
# 27  28             Tucumán                         Av. Sarmiento 525
# 28  29            Mendoza1                             Gutiérrez 349
# 29  30            Mendoza2                             Av. Colón 255
# 30  31           Bariloche                                 Mitre 252
#
#                   Localidad                  Provincia      Latitud  \
# 0    Ciudad de Buenos Aires     Ciudad de Buenos Aires  -34,5678060
# 1                      CABA                       CABA  -34,5790350
# 2                      CABA           C deBuenos Aires  -34,5959660
# 3    Ciudad de Buenos Aires                      Bs As  -34,6046850
# 4                   Capital                    Bs.As.   -34,6173080
# 5           Capital Federal     Ciudad de Buenos Aires  -34,6163030
# 6                    CapFed               Buenos Aires  -34,6228680
# 7                 Cap. Fed.               Buenos Aires  -34,6273060
# 8            Cap.   Federal               Buenos Aires  -34,6351340
# 9      Cdad de Buenos Aires     Ciudad de Buenos Aires  -34,6312570
# 10            Vicente López               Buenos Aires  -34,5301030
# 11                 Martínez                   B. Aires  -34,4944020
# 12                  Caseros                    B.Aires  -34,6059480
# 13                    Moron               Buenos Aires  -34,6458960
# 14                 Castelar  Provincia de Buenos Aires  -34,6393040
# 15                San Justo               Buenos Aires  -34,6813890
# 16                    Lanus             Prov de Bs As.  -34,6698050
# 17               Avellaneda               Buenos Aires  -34,6610600
# 18                  Quilmes                 Pcia Bs AS  -34,7222530
# 19                 La Plata                 Pcia Bs AS  -34,9207770
# 20            Mar del Plata               Buenos Aires  -37,9996910
# 21            Mar del Plata               Buenos Aires  -37,9997630
# 22                  Rosario                   Santa Fe  -32,9570300
# 23                  Rosario                   Santa Fe  -32,9627480
# 24                  Córdoba                    Córdoba  -31,4127470
# 25                   Coroba                    Córdoba  -31,4075380
# 26                  Cordoba                    Cordoba  -31,3612540
# 27    San Miguel de Tucumán                    Tucumán  -26,8180450
# 28                  Mendoza                    Mendoza  -32,8875310
# 29                  Mendoza                    Mendoza  -32,8942920
# 30  San Carlos de Bariloche                  Río Negro  -41,1338280
#
#        Longitud
# 0   -58,4495720
# 1   -58,4335660
# 2   -58,4051500
# 3   -58,3987640
# 4   -58,4161790
# 5   -58,4318490
# 6   -58,4464490
# 7   -58,4514980
# 8   -58,4615130
# 9   -58,4980630
# 10  -58,4800660
# 11  -58,4979510
# 12  -58,5633190
# 13  -58,6211490
# 14  -58,6556710
# 15  -58,5569190
# 16  -58,4113120
# 17  -58,3665150
# 18  -58,2575760
# 19  -57,9588890
# 20  -57,5463900
# 21  -57,5505770
# 22  -60,6413540
# 23  -60,7076290
# 24  -64,1864580
# 25  -64,2217380
# 26  -64,2378170
# 27  -65,2040710
# 28  -68,8433080
# 29  -68,8438020
# 30  -71,3063650

# %%
diccionario_sucursal = {
    'Columna_1' : {
        'Título': 'ID',
        'Descripción': 'Índice asociado a la sucursal.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_2' : {
        'Título': 'Sucursal',
        'Descripción': 'Nombre de la sucursal.',
        'Tipo de dato': 'String',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_3' : {
        'Título': 'Direccion',
        'Descripción': 'Dirección en la que se localiza la sucursal.',
        'Tipo de dato': 'String',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_4' : {
        'Título': 'Localidad',
        'Descripción': 'Nombre de la localidad en la que se encuentra.',
        'Tipo de dato': 'String',
        'Problemas': 'Algunos campos están sin normalizar.',
        'Soluciones': 'Normalizar dichos campos.'
    },
    'Columna_5' : {
        'Título': 'Provincia',
        'Descripción': 'Nombre de la provincia en la que se encuentra.',
        'Tipo de dato': 'String',
        'Problemas': 'Algunos campos están sin normalizar.',
        'Soluciones': 'Normalizar dichos campos.'
    },
    'Columna_6' : {
        'Título': 'Latitud',
        'Descripción': 'Coordenadas de latitud correspondientes.',
        'Tipo de dato': 'Decimal',
        'Problemas': 'Representación del punto decimal con coma.',
        'Soluciones': 'Transformar la representación del punto decimal.'
    },
    'Columna_7' : {
        'Título': 'Longitud',
        'Descripción': 'Coordenadas de longitud correspondientes.',
        'Tipo de dato': 'Decimal',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna',
        'Problemas': 'Representación del punto decimal con coma.',
        'Soluciones': 'Transformar la representación del punto decimal.'
    }
}

# %%
venta = pd.read_csv('./Datasets/Venta.csv', sep=',')
venta.head()
# Out:
#    IdVenta       Fecha Fecha_Entrega  IdCanal  IdCliente  IdSucursal  \
# 0        1  2018-03-09    2018-03-17        3        969          13
# 1        2  2018-12-28    2018-12-29        2        884          13
# 2        3  2016-03-28    2016-03-31        2       1722          13
# 3        4  2017-10-23    2017-10-24        3       2876          13
# 4        5  2017-11-22    2017-11-25        2        678          13
#
#    IdEmpleado  IdProducto  Precio  Cantidad
# 0        1674       42817  813.12       2.0
# 1        1674       42795  543.18       3.0
# 2        1674       42837  430.32       1.0
# 3        1674       42834  818.84       2.0
# 4        1674       42825  554.18       3.0

# %%
venta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46645 entries, 0 to 46644
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   IdVenta        46645 non-null  int64
#  1   Fecha          46645 non-null  object
#  2   Fecha_Entrega  46645 non-null  object
#  3   IdCanal        46645 non-null  int64
#  4   IdCliente      46645 non-null  int64
#  5   IdSucursal     46645 non-null  int64
#  6   IdEmpleado     46645 non-null  int64
#  7   IdProducto     46645 non-null  int64
#  8   Precio         45721 non-null  float64
#  9   Cantidad       45753 non-null  float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 3.6+ MB

# %%
venta.isna().sum()
# Out:
# IdVenta            0
# Fecha              0
# Fecha_Entrega      0
# IdCanal            0
# IdCliente          0
# IdSucursal         0
# IdEmpleado         0
# IdProducto         0
# Precio           924
# Cantidad         892
# dtype: int64

# %%
venta.describe()
# Out:
#             IdVenta       IdCanal     IdCliente    IdSucursal    IdEmpleado  \
# count  46645.000000  46645.000000  46645.000000  46645.000000  46645.000000
# mean   23398.589624      2.016958   1502.721514     14.781927   2488.720956
# std    13590.352830      0.743113    972.521043      8.878188    960.499762
# min        1.000000      1.000000      1.000000      1.000000   1011.000000
# 25%    11662.000000      1.000000    692.000000      7.000000   1574.000000
# 50%    23323.000000      2.000000   1360.000000     15.000000   2468.000000
# 75%    34984.000000      3.000000   2273.000000     23.000000   3433.000000
# max    48241.000000      3.000000   3407.000000     31.000000   3979.000000
#
#          IdProducto        Precio      Cantidad
# count  46645.000000  4.572100e+04  45753.000000
# mean   42901.305585  5.835634e+03      2.385395
# std       83.563413  2.498016e+05      3.547991
# min    42737.000000  3.000000e+00      1.000000
# 25%    42833.000000  4.380000e+02      2.000000
# 50%    42902.000000  6.536200e+02      2.000000
# 75%    42974.000000  1.789000e+03      3.000000
# max    43043.000000  3.373920e+07    300.000000

# %%
venta.nunique()
# Out:
# IdVenta          46645
# Fecha             1872
# Fecha_Entrega     2174
# IdCanal              3
# IdCliente         2969
# IdSucursal          30
# IdEmpleado         249
# IdProducto         283
# Precio             451
# Cantidad             9
# dtype: int64

# %%
diccionario_venta = {
    'Columna_1' : {
        'Título': 'IdVenta',
        'Descripción': 'Índice asociado a la factura.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Se saltea algunos registros.',
        'Soluciones': 'Dejar así ya que no afecta nuestro estudio y en un futuro los registros faltantes pueden ser agregados.'
    },
    'Columna_2' : {
        'Título': 'Fecha',
        'Descripción': 'Fecha en la que se efectuó la venta.',
        'Tipo de dato': 'Date',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_3' : {
        'Título': 'Fecha_Entrega',
        'Descripción': 'Fecha en la que se realizó la entrega del producto al cliente.',
        'Tipo de dato': 'Date',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_4' : {
        'Título': 'IdCanal',
        'Descripción': 'Índice correspondiente al canal en el que se realizó la venta.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Dato irrelevante ya que no tengo la tabla "Canal".',
        'Soluciones': 'Dropear la columna.'
    },
    'Columna_5' : {
        'Título': 'IdCliente',
        'Descripción': 'Índice correspondiente al cliente que realizó la orden.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_6' : {
        'Título': 'IdSucursal',
        'Descripción': 'Índice correspondiente a la sucursal en la que se realizó la venta.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Parecería que ninguno.',
        'Soluciones': 'Ninguna'
    },
    'Columna_7' : {
        'Título': 'IdEmpleado',
        'Descripción': 'Índice correspondiente al empleado que realizó la venta.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Dato irrelevante ya que no tengo la tabla "Empleado".',
        'Soluciones': 'Dropear la columna.'
    },
    'Columna_8' : {
        'Título': 'IdProducto',
        'Descripción': 'Índice correspondiente al producto vendido.',
        'Tipo de dato': 'Integer',
        'Problemas': 'Columna irrelevante ya que no tengo la tabla "Producto" para referirla.',
        'Soluciones': 'Dropear la columna ya que esta no es relevante en esta ocasión.'
    },
    'Columna_9' : {
        'Título': 'Precio',
        'Descripción': 'Valor unitario del producto vendido.',
        'Tipo de dato': 'Decimal',
        'Problemas': '924 nulos. Probablemente con presencia de outliers.',
        'Soluciones': 'Imputar los nulos por 0.0. Detectar y marcar outliers.'
    },
    'Columna_10' : {
        'Título': 'Cantidad',
        'Descripción': 'Número de productos vendidos.',
        'Tipo de dato': 'Decimal',
        'Problemas': '892 nulos. Probablemente con presencia de outliers.',
        'Soluciones': 'Imputar los nulos por 0.0. Detectar y marcar outliers.'
    }
}
